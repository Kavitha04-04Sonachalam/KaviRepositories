# %%
#importing pandas package
import pandas as pd

# %%
#import drive
from google.colab import drive

# %%
#mounting the drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#reading the CSV file using pandas
df=pd.read_csv("/content/drive/MyDrive/archive.zip")

# %%
#printing the file
df
# Out:
#      BodyFat Original Sex  Age   Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0      12.30        Y   M   23  69.9700  1.7200  36.2   93.1     85.2   94.5
# 1       6.10        Y   M   22  78.5900  1.8400  38.5   93.6     83.0   98.7
# 2      25.30        Y   M   22  69.8500  1.6800  34.0   95.8     87.9   99.2
# 3      10.40        Y   M   26  83.8000  1.8400  37.4  101.8     86.4  101.2
# 4      28.70        Y   M   24  83.5800  1.8100  34.4   97.3    100.0  101.9
# ..       ...      ...  ..  ...      ...     ...   ...    ...      ...    ...
# 431    30.40        N   F   23  59.8752  1.5621  31.3   89.0     71.0   98.5
# 432     7.47        N   F   21  48.5352  1.5748  29.5   79.0     62.5   89.0
# 433    11.98        N   F   20  51.7104  1.5748  31.5   81.5     61.5   90.0
# 434    11.24        N   F   22  50.8032  1.6510  30.5   85.0     64.0   88.0
# 435    17.49        N   F   24  47.6280  1.6002  26.0   79.3     63.0   86.6
#
# ...

# %%
#display the first 5 rows of a DataFrame
df.head()
# Out:
#    BodyFat Original Sex  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     12.3        Y   M   23   69.97    1.72  36.2   93.1     85.2   94.5
# 1      6.1        Y   M   22   78.59    1.84  38.5   93.6     83.0   98.7
# 2     25.3        Y   M   22   69.85    1.68  34.0   95.8     87.9   99.2
# 3     10.4        Y   M   26   83.80    1.84  37.4  101.8     86.4  101.2
# 4     28.7        Y   M   24   83.58    1.81  34.4   97.3    100.0  101.9
#
#    Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0   59.0  37.3   21.9    32.0     27.4   17.1
# 1   58.7  37.3   23.4    30.5     28.9   18.2
# 2   59.6  38.9   24.0    28.8     25.2   16.6
# 3   60.1  37.3   22.8    32.4     29.4   18.2
# 4   63.2  42.2   24.0    32.2     27.7   17.7

# %%
#display the last 5 rows of a DataFrame
df.tail()
# Out:
#      BodyFat Original Sex  Age   Weight  Height  Neck  Chest  Abdomen   Hip  \
# 431    30.40        N   F   23  59.8752  1.5621  31.3   89.0     71.0  98.5
# 432     7.47        N   F   21  48.5352  1.5748  29.5   79.0     62.5  89.0
# 433    11.98        N   F   20  51.7104  1.5748  31.5   81.5     61.5  90.0
# 434    11.24        N   F   22  50.8032  1.6510  30.5   85.0     64.0  88.0
# 435    17.49        N   F   24  47.6280  1.6002  26.0   79.3     63.0  86.6
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 431   56.0  36.2   21.0    28.0     24.5   16.3
# 432   49.0  33.0   20.0    25.0     22.0   15.5
# 433   49.5  32.0   19.5    27.5     22.5   15.0
# 434   45.0  32.0   19.5    24.0     21.5   15.0
# 435   46.0  33.5   19.0    24.0     21.5   14.0

# %%
#display the summary of the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 436 entries, 0 to 435
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   BodyFat   436 non-null    float64
#  1   Original  436 non-null    object
#  2   Sex       436 non-null    object
#  3   Age       436 non-null    int64
#  4   Weight    436 non-null    float64
#  5   Height    436 non-null    float64
#  6   Neck      436 non-null    float64
#  7   Chest     436 non-null    float64
#  8   Abdomen   436 non-null    float64
#  9   Hip       436 non-null    float64
#  10  Thigh     436 non-null    float64
#  11  Knee      436 non-null    float64
#  12  Ankle     436 non-null    float64
#  13  Biceps    436 non-null    float64
#  14  Forearm   436 non-null    float64
#  15  Wrist     436 non-null    float64
# dtypes: float64(13), int64(1), object(2)
# memory usage: 54.6+ KB

# %%
#generate descriptive statistics analysis
df.describe()
# Out:
#           BodyFat         Age      Weight      Height        Neck       Chest  \
# count  436.000000  436.000000  436.000000  436.000000  436.000000  436.000000
# mean    20.249839   34.545872   72.282203    1.734048   35.250917   94.158028
# std      7.502125   15.500099   15.464366    0.098359    3.837908   10.931688
# min      0.000000    1.000000   42.184800    0.750000   26.000000   43.000000
# 25%     15.022500   21.000000   59.875200    1.668780   31.500000   85.500000
# 50%     20.500000   28.500000   70.815800    1.730000   35.450000   93.050000
# 75%     25.410000   46.000000   81.560000    1.800000   38.300000  101.425000
# max     47.500000   81.000000  164.720000    1.970000   51.200000  136.200000
#
#           Abdomen         Hip       Thigh        Knee       Ankle      Biceps  \
# count  436.000000  436.000000  436.000000  436.000000  436.000000  436.000000
# mean    82.816055   98.652294   56.039679   37.365596   22.351835   29.897248
# ...

# %%
#dimention of the DataFrame
df.shape
# Out:
# (436, 16)

# %%
#print the column names
df.columns
# Out:
# Index(['BodyFat', 'Original', 'Sex', 'Age', 'Weight', 'Height', 'Neck',
#        'Chest', 'Abdomen', 'Hip', 'Thigh', 'Knee', 'Ankle', 'Biceps',
#        'Forearm', 'Wrist'],
#       dtype='object')

# %%
#print the data type of each column
df.dtypes
# Out:
# BodyFat     float64
# Original     object
# Sex          object
# Age           int64
# Weight      float64
# Height      float64
# Neck        float64
# Chest       float64
# Abdomen     float64
# Hip         float64
# Thigh       float64
# Knee        float64
# Ankle       float64
# Biceps      float64
# Forearm     float64
# Wrist       float64
# dtype: object

# %%
#printing a single column value
X=df['BodyFat']
X
# Out:
# 0      12.30
# 1       6.10
# 2      25.30
# 3      10.40
# 4      28.70
#        ...
# 431    30.40
# 432     7.47
# 433    11.98
# 434    11.24
# 435    17.49
# Name: BodyFat, Length: 436, dtype: float64

# %%
#printing multiple column
S=df[['Sex', 'Age']]
S
# Out:
#     Sex  Age
# 0     M   23
# 1     M   22
# 2     M   22
# 3     M   26
# 4     M   24
# ..   ..  ...
# 431   F   23
# 432   F   21
# 433   F   20
# 434   F   22
# 435   F   24
#
# [436 rows x 2 columns]

# %%
#access a group of rows and columns
df.loc[0:1]
# Out:
#    BodyFat Original Sex  Age  Weight  Height  Neck  Chest  Abdomen   Hip  \
# 0     12.3        Y   M   23   69.97    1.72  36.2   93.1     85.2  94.5
# 1      6.1        Y   M   22   78.59    1.84  38.5   93.6     83.0  98.7
#
#    Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0   59.0  37.3   21.9    32.0     27.4   17.1
# 1   58.7  37.3   23.4    30.5     28.9   18.2

# %%
#access a group of rows &columns using integer position
df.iloc[3,3]
# Out:
# 26

# %%
#filter the row using a condition 'Age'>50
df[df['Age']>50]
# Out:
#      BodyFat Original Sex  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 52       8.0        Y   M   51   62.26    1.72  36.5   89.7     82.0   89.1
# 55      22.6        Y   M   54   89.81    1.83  39.9  107.6    100.0   99.6
# 56      20.4        Y   M   58   82.33    1.73  39.1  100.0     99.8  102.5
# 57      28.0        Y   M   62   91.29    1.77  40.5  111.5    104.2  105.8
# 58      31.5        Y   M   54   91.85    1.80  40.5  115.4    105.3   97.0
# ..       ...      ...  ..  ...     ...     ...   ...    ...      ...    ...
# 247     11.0        Y   M   70   60.90    1.70  34.9   89.2     83.6   88.8
# 248     33.6        Y   M   72   91.17    1.77  40.9  108.5    105.0  104.5
# 249     29.3        Y   M   72   84.71    1.68  38.9  111.1    111.5  101.7
# 250     26.0        Y   M   72   86.52    1.79  38.9  108.3    101.3   97.8
# 251     31.9        Y   M   74   94.12    1.78  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# ...

# %%
#perform query on the DataFrame
df.query('Sex=="M"')
# Out:
#      BodyFat Original Sex  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0       12.3        Y   M   23   69.97    1.72  36.2   93.1     85.2   94.5
# 1        6.1        Y   M   22   78.59    1.84  38.5   93.6     83.0   98.7
# 2       25.3        Y   M   22   69.85    1.68  34.0   95.8     87.9   99.2
# 3       10.4        Y   M   26   83.80    1.84  37.4  101.8     86.4  101.2
# 4       28.7        Y   M   24   83.58    1.81  34.4   97.3    100.0  101.9
# ..       ...      ...  ..  ...     ...     ...   ...    ...      ...    ...
# 247     11.0        Y   M   70   60.90    1.70  34.9   89.2     83.6   88.8
# 248     33.6        Y   M   72   91.17    1.77  40.9  108.5    105.0  104.5
# 249     29.3        Y   M   72   84.71    1.68  38.9  111.1    111.5  101.7
# 250     26.0        Y   M   72   86.52    1.79  38.9  108.3    101.3   97.8
# 251     31.9        Y   M   74   94.12    1.78  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# ...

# %%
#checking for missing values
df.isnull()
# Out:
#      BodyFat  Original    Sex    Age  Weight  Height   Neck  Chest  Abdomen  \
# 0      False     False  False  False   False   False  False  False    False
# 1      False     False  False  False   False   False  False  False    False
# 2      False     False  False  False   False   False  False  False    False
# 3      False     False  False  False   False   False  False  False    False
# 4      False     False  False  False   False   False  False  False    False
# ..       ...       ...    ...    ...     ...     ...    ...    ...      ...
# 431    False     False  False  False   False   False  False  False    False
# 432    False     False  False  False   False   False  False  False    False
# 433    False     False  False  False   False   False  False  False    False
# 434    False     False  False  False   False   False  False  False    False
# 435    False     False  False  False   False   False  False  False    False
#
#        Hip  Thigh   Knee  Ankle  Biceps  Forearm  Wrist
# ...

# %%
#checking for missing value
df.notnull()
# Out:
#      BodyFat  Original   Sex   Age  Weight  Height  Neck  Chest  Abdomen  \
# 0       True      True  True  True    True    True  True   True     True
# 1       True      True  True  True    True    True  True   True     True
# 2       True      True  True  True    True    True  True   True     True
# 3       True      True  True  True    True    True  True   True     True
# 4       True      True  True  True    True    True  True   True     True
# ..       ...       ...   ...   ...     ...     ...   ...    ...      ...
# 431     True      True  True  True    True    True  True   True     True
# 432     True      True  True  True    True    True  True   True     True
# 433     True      True  True  True    True    True  True   True     True
# 434     True      True  True  True    True    True  True   True     True
# 435     True      True  True  True    True    True  True   True     True
#
#       Hip  Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# ...

# %%
#drop the rows with missing values
df.dropna()
# Out:
#      BodyFat Original Sex  Age   Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0      12.30        Y   M   23  69.9700  1.7200  36.2   93.1     85.2   94.5
# 1       6.10        Y   M   22  78.5900  1.8400  38.5   93.6     83.0   98.7
# 2      25.30        Y   M   22  69.8500  1.6800  34.0   95.8     87.9   99.2
# 3      10.40        Y   M   26  83.8000  1.8400  37.4  101.8     86.4  101.2
# 4      28.70        Y   M   24  83.5800  1.8100  34.4   97.3    100.0  101.9
# ..       ...      ...  ..  ...      ...     ...   ...    ...      ...    ...
# 431    30.40        N   F   23  59.8752  1.5621  31.3   89.0     71.0   98.5
# 432     7.47        N   F   21  48.5352  1.5748  29.5   79.0     62.5   89.0
# 433    11.98        N   F   20  51.7104  1.5748  31.5   81.5     61.5   90.0
# 434    11.24        N   F   22  50.8032  1.6510  30.5   85.0     64.0   88.0
# 435    17.49        N   F   24  47.6280  1.6002  26.0   79.3     63.0   86.6
#
# ...

# %%
#fill the missing values as 10
df.fillna(10)
# Out:
#      BodyFat Original Sex  Age   Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0      12.30        Y   M   23  69.9700  1.7200  36.2   93.1     85.2   94.5
# 1       6.10        Y   M   22  78.5900  1.8400  38.5   93.6     83.0   98.7
# 2      25.30        Y   M   22  69.8500  1.6800  34.0   95.8     87.9   99.2
# 3      10.40        Y   M   26  83.8000  1.8400  37.4  101.8     86.4  101.2
# 4      28.70        Y   M   24  83.5800  1.8100  34.4   97.3    100.0  101.9
# ..       ...      ...  ..  ...      ...     ...   ...    ...      ...    ...
# 431    30.40        N   F   23  59.8752  1.5621  31.3   89.0     71.0   98.5
# 432     7.47        N   F   21  48.5352  1.5748  29.5   79.0     62.5   89.0
# 433    11.98        N   F   20  51.7104  1.5748  31.5   81.5     61.5   90.0
# 434    11.24        N   F   22  50.8032  1.6510  30.5   85.0     64.0   88.0
# 435    17.49        N   F   24  47.6280  1.6002  26.0   79.3     63.0   86.6
#
# ...

# %%
# Grouping by the 'Age' column
grouped_by_Sex = df.groupby('Sex')
# Displaying the groups
for name, group in grouped_by_Sex:
   print( name)
   print( group)
# Out:
# F
#      BodyFat Original Sex  Age   Weight   Height  Neck  Chest  Abdomen   Hip  \
# 252    23.07        N   F   22  49.4424  1.61290  28.8   76.1     62.8  90.2
# 253    29.50        N   F   22  60.7824  1.57480  31.2   87.3     68.0  94.0
# 254    26.99        N   F   21  63.0504  1.61798  30.8   83.7     71.0  94.0
# 255    20.25        N   F   20  53.0712  1.68148  30.0   78.0     63.5  90.5
# 256    19.95        N   F   20  59.4216  1.73228  32.5   84.2     65.0  93.2
# ..       ...      ...  ..  ...      ...      ...   ...    ...      ...   ...
# 431    30.40        N   F   23  59.8752  1.56210  31.3   89.0     71.0  98.5
# 432     7.47        N   F   21  48.5352  1.57480  29.5   79.0     62.5  89.0
# 433    11.98        N   F   20  51.7104  1.57480  31.5   81.5     61.5  90.0
# 434    11.24        N   F   22  50.8032  1.65100  30.5   85.0     64.0  88.0
# 435    17.49        N   F   24  47.6280  1.60020  26.0   79.3     63.0  86.6
#
# ...

# %%
#Sorting the DataFrame by the 'Age' column in ascending order
#Sorting the DataFrame by the 'Sex' column in descending order
sorted_df = df.sort_values(by=['Age', 'Sex'], ascending=[True, False])
# Displaying the sorted DataFrame
sorted_df
# Out:
#      BodyFat Original Sex  Age   Weight   Height  Neck  Chest  Abdomen    Hip  \
# 371    26.68        N   F    1  62.5968  1.64338  34.0   86.5     72.5   98.5
# 265    14.93        N   F   18  53.9784  1.60020  30.5   86.0     66.4   92.3
# 274    18.24        N   F   18  48.5352  1.61290  29.5   82.5     63.2   89.2
# 275    24.43        N   F   18  70.3080  1.72720  33.0   90.1     73.0  103.0
# 305    30.22        N   F   18  68.4936  1.60020  32.5   91.0     77.2  105.0
# ..       ...      ...  ..  ...      ...      ...   ...    ...      ...    ...
# 248    33.60        Y   M   72  91.1700  1.77000  40.9  108.5    105.0  104.5
# 249    29.30        Y   M   72  84.7100  1.68000  38.9  111.1    111.5  101.7
# 250    26.00        Y   M   72  86.5200  1.79000  38.9  108.3    101.3   97.8
# 251    31.90        Y   M   74  94.1200  1.78000  40.8  112.4    108.5  107.1
# 78     21.50        Y   M   81  73.1400  1.78000  37.8   96.4     95.4   99.3
#
# ...

# %%
# Creating a pivot table
pivot_table = df.pivot_table(values='Sex', index='Height', columns='Age')
# Displaying the pivot table
pivot_table
# Out:
# <ipython-input-29-d2f999b423fe>:2: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   pivot_table = df.pivot_table(values='Sex', index='Height', columns='Age')
# Empty DataFrame
# Columns: []
# Index: [0.75, 1.5367, 1.54178, 1.5621, 1.5748, 1.5875, 1.6002, 1.60528, 1.60782, 1.6129, 1.61798, 1.6256, 1.63, 1.63322, 1.6383, 1.64, 1.64338, 1.6477, 1.65, 1.651, 1.65862, 1.66, 1.6637, 1.66878, 1.67, 1.6764, 1.68, 1.68148, 1.68402, 1.68656, 1.6891, 1.69, 1.69164, 1.69418, 1.7, 1.7018, 1.70688, 1.70942, 1.71, 1.7145, 1.72, 1.7272, 1.73, 1.73228, 1.73482, 1.7399, 1.74, 1.74498, 1.75, 1.7526, 1.76, 1.7653, 1.77, 1.77038, 1.778, 1.78, 1.78308, 1.79, 1.7907, 1.79578, 1.8, 1.8034, 1.81, 1.82, 1.83, 1.84, 1.85, 1.86, 1.87, 1.88, 1.89, 1.9, 1.91, 1.92, 1.93, 1.97]
#
# [76 rows x 0 columns]

# %%
# Using melt to transform wide to long format
df_long = pd.melt(df, id_vars=['Age'], var_name='Sex', value_name='BodyFat')
df_long
# Out:
# <ipython-input-14-427bb132a9fc>:2: FutureWarning: This dataframe has a column name that matches the 'value_name' column name of the resulting Dataframe. In the future this will raise an error, please set the 'value_name' parameter of DataFrame.melt to a unique name.
#   df_long = pd.melt(df, id_vars=['Age'], var_name='Sex', value_name='BodyFat')
#       Age      Sex BodyFat
# 0      23  BodyFat    12.3
# 1      22  BodyFat     6.1
# 2      22  BodyFat    25.3
# 3      26  BodyFat    10.4
# 4      24  BodyFat    28.7
# ...   ...      ...     ...
# 6535   23    Wrist    16.3
# 6536   21    Wrist    15.5
# 6537   20    Wrist    15.0
# 6538   22    Wrist    15.0
# 6539   24    Wrist    14.0
#
# [6540 rows x 3 columns]

# %%
# Create a new DataFrame by copying the existing one
df2 = df.copy()
df2
# Out:
#      BodyFat Original Sex  Age   Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0      12.30        Y   M   23  69.9700  1.7200  36.2   93.1     85.2   94.5
# 1       6.10        Y   M   22  78.5900  1.8400  38.5   93.6     83.0   98.7
# 2      25.30        Y   M   22  69.8500  1.6800  34.0   95.8     87.9   99.2
# 3      10.40        Y   M   26  83.8000  1.8400  37.4  101.8     86.4  101.2
# 4      28.70        Y   M   24  83.5800  1.8100  34.4   97.3    100.0  101.9
# ..       ...      ...  ..  ...      ...     ...   ...    ...      ...    ...
# 431    30.40        N   F   23  59.8752  1.5621  31.3   89.0     71.0   98.5
# 432     7.47        N   F   21  48.5352  1.5748  29.5   79.0     62.5   89.0
# 433    11.98        N   F   20  51.7104  1.5748  31.5   81.5     61.5   90.0
# 434    11.24        N   F   22  50.8032  1.6510  30.5   85.0     64.0   88.0
# 435    17.49        N   F   24  47.6280  1.6002  26.0   79.3     63.0   86.6
#
# ...

# %%
# Concatenating along rows (axis=1)
result = pd.concat([df,df2], axis=1)
result
# Out:
#      BodyFat Original Sex  Age   Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0      12.30        Y   M   23  69.9700  1.7200  36.2   93.1     85.2   94.5
# 1       6.10        Y   M   22  78.5900  1.8400  38.5   93.6     83.0   98.7
# 2      25.30        Y   M   22  69.8500  1.6800  34.0   95.8     87.9   99.2
# 3      10.40        Y   M   26  83.8000  1.8400  37.4  101.8     86.4  101.2
# 4      28.70        Y   M   24  83.5800  1.8100  34.4   97.3    100.0  101.9
# ..       ...      ...  ..  ...      ...     ...   ...    ...      ...    ...
# 431    30.40        N   F   23  59.8752  1.5621  31.3   89.0     71.0   98.5
# 432     7.47        N   F   21  48.5352  1.5748  29.5   79.0     62.5   89.0
# 433    11.98        N   F   20  51.7104  1.5748  31.5   81.5     61.5   90.0
# 434    11.24        N   F   22  50.8032  1.6510  30.5   85.0     64.0   88.0
# 435    17.49        N   F   24  47.6280  1.6002  26.0   79.3     63.0   86.6
#
# ...

# %%
# Merge DataFrames on the 'Age' column
merged_df = pd.merge(S,df_long,on='Age')
merged_df
# Out:
#        Sex_x  Age    Sex_y BodyFat
# 0          M   23  BodyFat    12.3
# 1          M   23  BodyFat    11.7
# 2          M   23  BodyFat     9.4
# 3          M   23  BodyFat    10.3
# 4          M   23  BodyFat   20.28
# ...      ...  ...      ...     ...
# 127555     F    1     Knee    37.5
# 127556     F    1    Ankle    23.0
# 127557     F    1   Biceps    28.5
# 127558     F    1  Forearm    24.5
# 127559     F    1    Wrist    15.5
#
# [127560 rows x 4 columns]

# %%
# Define a function to square each element
def square_element(x):
    return x ** 2
# Apply the function to each element in the DataFrame
result = X.apply(square_element)
result
# Out:
# 0      151.2900
# 1       37.2100
# 2      640.0900
# 3      108.1600
# 4      823.6900
#          ...
# 431    924.1600
# 432     55.8009
# 433    143.5204
# 434    126.3376
# 435    305.9001
# Name: BodyFat, Length: 436, dtype: float64

# %%
# Shift the values in the 'Age' column by one position
df['Shifted_Values'] = df['Age'].shift()
df
# Out:
#      BodyFat Original Sex  Age   Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0      12.30        Y   M   23  69.9700  1.7200  36.2   93.1     85.2   94.5
# 1       6.10        Y   M   22  78.5900  1.8400  38.5   93.6     83.0   98.7
# 2      25.30        Y   M   22  69.8500  1.6800  34.0   95.8     87.9   99.2
# 3      10.40        Y   M   26  83.8000  1.8400  37.4  101.8     86.4  101.2
# 4      28.70        Y   M   24  83.5800  1.8100  34.4   97.3    100.0  101.9
# ..       ...      ...  ..  ...      ...     ...   ...    ...      ...    ...
# 431    30.40        N   F   23  59.8752  1.5621  31.3   89.0     71.0   98.5
# 432     7.47        N   F   21  48.5352  1.5748  29.5   79.0     62.5   89.0
# 433    11.98        N   F   20  51.7104  1.5748  31.5   81.5     61.5   90.0
# 434    11.24        N   F   22  50.8032  1.6510  30.5   85.0     64.0   88.0
# 435    17.49        N   F   24  47.6280  1.6002  26.0   79.3     63.0   86.6
#
# ...

# %%
#calculaye mean for specific column
df['Age'].mean()
# Out:
# 34.54587155963303

# %%
#calculaye mean for specific column
df['Height'].median()
# Out:
# 1.73

# %%
#calculaye std for specific colum
df['Age'].std()
# Out:
# 15.500098818283986

# %%
#calculaye correlation for specific colum
df.corr()
# Out:
# <ipython-input-58-c30769e9e14a>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                  BodyFat       Age    Weight    Height      Neck     Chest  \
# BodyFat         1.000000  0.015808  0.345822 -0.150693  0.121790  0.310410
# Age             0.015808  1.000000  0.519842  0.372990  0.685648  0.622099
# Weight          0.345822  0.519842  1.000000  0.589737  0.889274  0.908069
# Height         -0.150693  0.372990  0.589737  1.000000  0.591184  0.493097
# Neck            0.121790  0.685648  0.889274  0.591184  1.000000  0.878798
# Chest           0.310410  0.622099  0.908069  0.493097  0.878798  1.000000
# Abdomen         0.357465  0.686124  0.932298  0.500683  0.905187  0.923944
# Hip             0.588482  0.141997  0.805107  0.294508  0.550018  0.652564
# ...

# %%
# Rename the 'BodyFat' column to 'Fat'
df = df.rename(columns={'BodyFat': 'Fat'})
df
# Out:
#        Fat Original Sex  Age   Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0    12.30        Y   M   23  69.9700  1.7200  36.2   93.1     85.2   94.5
# 1     6.10        Y   M   22  78.5900  1.8400  38.5   93.6     83.0   98.7
# 2    25.30        Y   M   22  69.8500  1.6800  34.0   95.8     87.9   99.2
# 3    10.40        Y   M   26  83.8000  1.8400  37.4  101.8     86.4  101.2
# 4    28.70        Y   M   24  83.5800  1.8100  34.4   97.3    100.0  101.9
# ..     ...      ...  ..  ...      ...     ...   ...    ...      ...    ...
# 431  30.40        N   F   23  59.8752  1.5621  31.3   89.0     71.0   98.5
# 432   7.47        N   F   21  48.5352  1.5748  29.5   79.0     62.5   89.0
# 433  11.98        N   F   20  51.7104  1.5748  31.5   81.5     61.5   90.0
# 434  11.24        N   F   22  50.8032  1.6510  30.5   85.0     64.0   88.0
# 435  17.49        N   F   24  47.6280  1.6002  26.0   79.3     63.0   86.6
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist  Shifted_Values
# ...

# %%
# Drop the row with index 1
new_df = df.drop(1)
new_df
# Out:
#        Fat Original Sex  Age   Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0    12.30        Y   M   23  69.9700  1.7200  36.2   93.1     85.2   94.5
# 2    25.30        Y   M   22  69.8500  1.6800  34.0   95.8     87.9   99.2
# 3    10.40        Y   M   26  83.8000  1.8400  37.4  101.8     86.4  101.2
# 4    28.70        Y   M   24  83.5800  1.8100  34.4   97.3    100.0  101.9
# 5    20.90        Y   M   24  95.3700  1.9000  39.0  104.5     94.4  107.8
# ..     ...      ...  ..  ...      ...     ...   ...    ...      ...    ...
# 431  30.40        N   F   23  59.8752  1.5621  31.3   89.0     71.0   98.5
# 432   7.47        N   F   21  48.5352  1.5748  29.5   79.0     62.5   89.0
# 433  11.98        N   F   20  51.7104  1.5748  31.5   81.5     61.5   90.0
# 434  11.24        N   F   22  50.8032  1.6510  30.5   85.0     64.0   88.0
# 435  17.49        N   F   24  47.6280  1.6002  26.0   79.3     63.0   86.6
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist  Shifted_Values
# ...

# %%
# Save the DataFrame to a CSV file
df.to_csv('Output.csv', index=False)
df
# Out:
#        Fat Original Sex  Age   Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0    12.30        Y   M   23  69.9700  1.7200  36.2   93.1     85.2   94.5
# 1     6.10        Y   M   22  78.5900  1.8400  38.5   93.6     83.0   98.7
# 2    25.30        Y   M   22  69.8500  1.6800  34.0   95.8     87.9   99.2
# 3    10.40        Y   M   26  83.8000  1.8400  37.4  101.8     86.4  101.2
# 4    28.70        Y   M   24  83.5800  1.8100  34.4   97.3    100.0  101.9
# ..     ...      ...  ..  ...      ...     ...   ...    ...      ...    ...
# 431  30.40        N   F   23  59.8752  1.5621  31.3   89.0     71.0   98.5
# 432   7.47        N   F   21  48.5352  1.5748  29.5   79.0     62.5   89.0
# 433  11.98        N   F   20  51.7104  1.5748  31.5   81.5     61.5   90.0
# 434  11.24        N   F   22  50.8032  1.6510  30.5   85.0     64.0   88.0
# 435  17.49        N   F   24  47.6280  1.6002  26.0   79.3     63.0   86.6
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist  Shifted_Values
# ...

# %%
# Save the DataFrame to an Excel file
df.to_excel('output.xlsx', index=True)
df
# Out:
#      BodyFat Original Sex  Age   Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0      12.30        Y   M   23  69.9700  1.7200  36.2   93.1     85.2   94.5
# 1       6.10        Y   M   22  78.5900  1.8400  38.5   93.6     83.0   98.7
# 2      25.30        Y   M   22  69.8500  1.6800  34.0   95.8     87.9   99.2
# 3      10.40        Y   M   26  83.8000  1.8400  37.4  101.8     86.4  101.2
# 4      28.70        Y   M   24  83.5800  1.8100  34.4   97.3    100.0  101.9
# ..       ...      ...  ..  ...      ...     ...   ...    ...      ...    ...
# 431    30.40        N   F   23  59.8752  1.5621  31.3   89.0     71.0   98.5
# 432     7.47        N   F   21  48.5352  1.5748  29.5   79.0     62.5   89.0
# 433    11.98        N   F   20  51.7104  1.5748  31.5   81.5     61.5   90.0
# 434    11.24        N   F   22  50.8032  1.6510  30.5   85.0     64.0   88.0
# 435    17.49        N   F   24  47.6280  1.6002  26.0   79.3     63.0   86.6
#
# ...

# %%
#loading the data using CSV file
CSV=pd.read_csv("/content/drive/MyDrive/archive.zip")

# %%
#print the dataset as CSV
CSV
# Out:
#      BodyFat Original Sex  Age   Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0      12.30        Y   M   23  69.9700  1.7200  36.2   93.1     85.2   94.5
# 1       6.10        Y   M   22  78.5900  1.8400  38.5   93.6     83.0   98.7
# 2      25.30        Y   M   22  69.8500  1.6800  34.0   95.8     87.9   99.2
# 3      10.40        Y   M   26  83.8000  1.8400  37.4  101.8     86.4  101.2
# 4      28.70        Y   M   24  83.5800  1.8100  34.4   97.3    100.0  101.9
# ..       ...      ...  ..  ...      ...     ...   ...    ...      ...    ...
# 431    30.40        N   F   23  59.8752  1.5621  31.3   89.0     71.0   98.5
# 432     7.47        N   F   21  48.5352  1.5748  29.5   79.0     62.5   89.0
# 433    11.98        N   F   20  51.7104  1.5748  31.5   81.5     61.5   90.0
# 434    11.24        N   F   22  50.8032  1.6510  30.5   85.0     64.0   88.0
# 435    17.49        N   F   24  47.6280  1.6002  26.0   79.3     63.0   86.6
#
# ...

# %%
# load the data set using excel
df.to_excel('output.xlsx', index=True)
df
# Out:
#      BodyFat Original Sex  Age   Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0      12.30        Y   M   23  69.9700  1.7200  36.2   93.1     85.2   94.5
# 1       6.10        Y   M   22  78.5900  1.8400  38.5   93.6     83.0   98.7
# 2      25.30        Y   M   22  69.8500  1.6800  34.0   95.8     87.9   99.2
# 3      10.40        Y   M   26  83.8000  1.8400  37.4  101.8     86.4  101.2
# 4      28.70        Y   M   24  83.5800  1.8100  34.4   97.3    100.0  101.9
# ..       ...      ...  ..  ...      ...     ...   ...    ...      ...    ...
# 431    30.40        N   F   23  59.8752  1.5621  31.3   89.0     71.0   98.5
# 432     7.47        N   F   21  48.5352  1.5748  29.5   79.0     62.5   89.0
# 433    11.98        N   F   20  51.7104  1.5748  31.5   81.5     61.5   90.0
# 434    11.24        N   F   22  50.8032  1.6510  30.5   85.0     64.0   88.0
# 435    17.49        N   F   24  47.6280  1.6002  26.0   79.3     63.0   86.6
#
# ...
